# %%
from nltk.stem import PorterStemmer , WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from spacy import parts_of_speech

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
sentence = "I was in Appple yesterday with Mashary and we ate pizza"


doc = nlp(sentence)

print(doc.ents)

for ent in doc.ents : 
    print(f"{ent.text} { ent.label_} { spacy.explain(ent.label_)}" )
# Out:
# (Apple, yesterday, Mashary)
# Apple ORG Companies, agencies, institutions, etc.
# yesterday DATE Absolute or relative dates or periods
# Mashary PERSON People, including fictional

# %%
import textblob as textblob

txt = textblob.TextBlob
correct = txt(sentence).correct()
correct
# Out:
# TextBlob("I was in Apple yesterday with Zachary and we ate penza")
