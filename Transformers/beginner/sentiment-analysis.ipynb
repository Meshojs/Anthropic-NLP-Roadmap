# %% [markdown]
# This movie wasn't really great

# %%
from transformers import pipeline


c = pipeline("sentiment-analysis")

c(["this moview is really good" , "i didnt like that moview"])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 6904.42it/s]
# [{'label': 'POSITIVE', 'score': 0.9998655319213867},
#  {'label': 'NEGATIVE', 'score': 0.9652479290962219}]
